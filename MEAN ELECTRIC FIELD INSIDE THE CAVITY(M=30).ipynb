# %%
import numpy as np
import matplotlib.pyplot as plt
import math
from copy import deepcopy
import matplotlib.colors as mcolors
import matplotlib.cm as cm
from matplotlib.ticker import ScalarFormatter
import pandas as pd

# %%
#formato unificado de gráficas
#formato unificado de gráficas
plt.rcParams['figure.figsize']=13,9.1
plt.rcParams['font.size']=30
plt.rcParams['lines.linewidth']=2.1
plt.rcParams['text.usetex']=True

# %%
M=30
X_L=np.arange(0.4,0.6,0.001)
w1=1.
m=np.arange(1,M+1)
g=np.arange(0,2,0.01) #Here I have all the values of the coupling constant
MeanField=[]
MaxField=[]
#I will do everything for M=30 like in David's document
Delta_r_p1_M30=np.load("Delta_r_p1_M30.npy") #Here I have all the values of the renormalized qubit frequency
epsilon_r_p1_M30=np.load("epsilon_r_p1_M30.npy") #Here I have all the values of the renormalized bias

# %%
def mean_field(coup,n,er,Dr,x_l):
    part_1=(coup*np.sin(n*np.pi/2)*np.sqrt(n)*er*np.sin(n*np.pi*x_l))/(np.sqrt(m*w1)*(1+0.003*(n-1))*np.sqrt(er*er + Dr*Dr))
    return (np.nansum(part_1)/(coup+0.0001))**2 #I put a safe value to no divide by zero

# %%
#FOR THE MEAN FIELD GRAPHIC

#I will modify just this three variables:
#gaux=g[10]
#Dr_aux=Delta_r_p1_M30[10]
#er_aux=epsilon_r_p1_M30[10]

#for i in range(np.size(X_L)):
    #x_l_aux=X_L[i]
    #now I just calculate the mean field
    #field_aux=mean_field(gaux,m,er_aux,Dr_aux,x_l_aux)
    #MeanField.append(field_aux)

# %%
#FOR THE MAX FIELD INSET
for i in range(np.size(g)):
    gaux=g[i]
    Dr_aux=Delta_r_p1_M30[i]
    er_aux=epsilon_r_p1_M30[i]
    x_l_max=0.5
    #now I just calculate the mean field
    field_max=mean_field(gaux,m,er_aux,Dr_aux,x_l_max)
    MaxField.append(field_max)

# %%
#FOR THE MEAN FIELD GRAPHIC

#plt.plot(X_L,MeanField)
#np.save("Mean_Field_M30_g0.1",MeanField) #I should modify this each time too
#plt.xlabel('$x/L$')
#plt.ylabel('$ |<E^+>/g|^2 [a.u.]$')

# %%
#FOR THE MAX FIELD INSET

plt.plot(g,MaxField, color="DarkRed")
np.save("Max_Field_M30",MaxField) #I should modify this each time too
plt.xlim(0,2)
plt.ylim(0,210)
plt.xlabel('$g$')
plt.ylabel('$ |<E^+>_{max}/g|^2$')
#plt.savefig('Emax_vs_g.png')
plt.show()

# %%
#FOR THE MEAN FIELD GRAPHIC

MeanField_M30_g0_1=np.load("Mean_Field_M30_g0.1.npy")
MeanField_M30_g0_2=np.load("Mean_Field_M30_g0.2.npy")
MeanField_M30_g0_3=np.load("Mean_Field_M30_g0.3.npy")
MeanField_M30_g0_4=np.load("Mean_Field_M30_g0.4.npy")
MeanField_M30_g0_5=np.load("Mean_Field_M30_g0.5.npy")
MeanField_M30_g0_6=np.load("Mean_Field_M30_g0.6.npy")
MeanField_M30_g0_7=np.load("Mean_Field_M30_g0.7.npy")
MeanField_M30_g0_8=np.load("Mean_Field_M30_g0.8.npy")
MeanField_M30_g0_9=np.load("Mean_Field_M30_g0.9.npy")
MeanField_M30_g1=np.load("Mean_Field_M30_g1.npy")
MeanField_M30_g1_1=np.load("Mean_Field_M30_g1.1.npy")
MeanField_M30_g1_2=np.load("Mean_Field_M30_g1.2.npy")
MeanField_M30_g1_3=np.load("Mean_Field_M30_g1.3.npy")
MeanField_M30_g1_4=np.load("Mean_Field_M30_g1.4.npy")
MeanField_M30_g1_5=np.load("Mean_Field_M30_g1.5.npy")
MeanField_M30_g1_8=np.load("Mean_Field_M30_g1.8.npy")

# %%
#FOR THE MEAN FIELD GRAPHIC
#cmap = plt.get_cmap('viridis')
#Numbers=[MeanField_M30_g0_2,MeanField_M30_g0_4,MeanField_M30_g0_5,MeanField_M30_g0_6,MeanField_M30_g0_7,MeanField_M30_g0_8,MeanField_M30_g0_9,MeanField_M30_g1,MeanField_M30_g1_1,MeanField_M30_g1_2,MeanField_M30_g1_5]
#labels=["$g<0.4$","$g=0.4$","$g=0.5$","$g=0.6$","$g=0.7$","$g=0.8$","$g=0.9$","$g=1$","$g=1.1$","$g=1.2$","$g>1.2$"]
#colors = iter(cmap(np.linspace(0, 1, len(Numbers))))
#c = next(colors)

#for i in range (len(Numbers)):
#    plt.plot(X_L,Numbers[i],label=labels[i],c=next(colors))
    
#plt.xlabel('$x/L$')
#plt.ylabel('$ |<E^+>/g|^2 [a.u.]$')
#plt.legend(loc='best',edgecolor="None")
#plt.savefig('Campoelectricoentregalcuadrado.png')
#plt.show()

# %%
cmap = plt.get_cmap('viridis')
Numbers=[MeanField_M30_g0_2,MeanField_M30_g0_4,MeanField_M30_g0_5,MeanField_M30_g0_6,MeanField_M30_g0_7,MeanField_M30_g0_8,MeanField_M30_g0_9,MeanField_M30_g1,MeanField_M30_g1_1,MeanField_M30_g1_2,MeanField_M30_g1_5]
labels=["$0.2$","$0.4$","$0.5$","$0.6$","$0.7$","$0.8$","$0.9$","$1$","$1.1$","$1.2$","$1.5$"]
colors = iter(cmap(np.linspace(0, 1, len(Numbers))))

fig, ax1 = plt.subplots()
#fig.set_size_inches([11,7.1])

for i in range (len(Numbers)):
    ax1.plot(X_L,Numbers[i],label=labels[i],c=next(colors))
ax1.legend(bbox_to_anchor=(1.23,1.05),title="$g/\omega_c$")
ax1.tick_params(top=True,bottom=True,right=True,left=True, direction="in",width=1,length=6,pad=8,labelsize=30)
ax1.set_xlabel('$x/L$',fontdict={'fontsize':33,'color':'k'},labelpad=8)
ax1.set_ylabel('$ |<E^+(x)>/(g/\omega_c)|^2$',fontdict={'fontsize':33,'color':'k'},labelpad=8)

left, bottom, width, height = [0.23, 0.59, 0.2, 0.25]
ax2 = fig.add_axes([left, bottom, width, height])
ax2.plot(g,MaxField, color="DarkRed")
ax2.tick_params(top=True,bottom=True,right=True,left=True, direction="in",width=1,length=4,pad=6,labelsize=28)
ax2.set_xlabel('$g/\omega_c$',fontdict={'fontsize':26,'color':'k'},labelpad=6)
ax2.set_ylabel('$ |<E^+(x)>/(g/\omega_c)|_{max}^2$',fontdict={'fontsize':26,'color':'k'},labelpad=5)
ax2.set_xlim([0,2])
ax2.set_ylim([0,210])
ax2.set_xticks([0.0,0.5,1.0,1.5,2.0])
ax2.set_yticks([50,100,150,200])

fig.savefig('Campoelectricoentregalcuadrado_coninset.pdf',bbox_inches='tight')

#plt.show()

# %%
#ax1.plot(X_L,MeanField_M30_g0_2,label="$g<0.4$")
#ax1.plot(X_L,MeanField_M30_g0_4,label="$g=0.4$")
#ax1.plot(X_L,MeanField_M30_g0_5,label="$g=0.5$")
#ax1.plot(X_L,MeanField_M30_g0_6,label="$g=0.6$")
#ax1.plot(X_L,MeanField_M30_g0_7,label="$g=0.7$")
#ax1.plot(X_L,MeanField_M30_g0_8,label="$g=0.8$")
#ax1.plot(X_L,MeanField_M30_g0_9,label="$g=0.9$")
#ax1.plot(X_L,MeanField_M30_g1,label="$g=1$")
#ax1.plot(X_L,MeanField_M30_g1_1,label="$g=1.1$")
#ax1.plot(X_L,MeanField_M30_g1_2,label="$g=1.2$")
#ax1.plot(X_L,MeanField_M30_g1_5,label="$g>1.2$")
