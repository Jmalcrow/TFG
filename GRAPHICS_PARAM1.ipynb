# %%
import numpy as np
import matplotlib.pyplot as plt
import math
from copy import deepcopy
import matplotlib.colors as mcolors
import matplotlib.cm as cm
from matplotlib.ticker import ScalarFormatter

# %%
#formato unificado de gráficas
plt.rcParams['figure.figsize']=8.5,5.1
plt.rcParams['font.size']=15
plt.rcParams['lines.linewidth']=1.5
plt.rcParams['text.usetex']=True

# %%
#X-axis, different values of coupling constant
g=np.arange(0,2,0.01)
#Y-axis, different values of Energy of Ground State
E_gs_p1_M1=np.load("EGS_p1_M1.npy")
E_gs_p1_M10=np.load("EGS_p1_M10.npy")
E_gs_p1_M30=np.load("EGS_p1_M30.npy")
E_gs_p1_M60=np.load("EGS_p1_M60.npy")
E_gs_p1_M100=np.load("EGS_p1_M100.npy")
E_gs_p1_M200=np.load("EGS_p1_M200.npy")
E_gs_p1_M500=np.load("EGS_p1_M500.npy")
E_gs_p1_M1000=np.load("EGS_p1_M1000.npy")
#Y-axis, different values of renormalized qubit frequency Delta_r
Delta_r_p1_M1=np.load("Delta_r_p1_M1.npy")
Delta_r_p1_M10=np.load("Delta_r_p1_M10.npy")
Delta_r_p1_M30=np.load("Delta_r_p1_M30.npy")
Delta_r_p1_M60=np.load("Delta_r_p1_M60.npy")
Delta_r_p1_M100=np.load("Delta_r_p1_M100.npy")
Delta_r_p1_M200=np.load("Delta_r_p1_M200.npy")
Delta_r_p1_M500=np.load("Delta_r_p1_M500.npy")
Delta_r_p1_M1000=np.load("Delta_r_p1_M1000.npy")
#Y-axis, different values of renormalized bias epsilon_r
epsilon_r_p1_M1=np.load("epsilon_r_p1_M1.npy")
epsilon_r_p1_M10=np.load("epsilon_r_p1_M10.npy")
epsilon_r_p1_M30=np.load("epsilon_r_p1_M30.npy")
epsilon_r_p1_M60=np.load("epsilon_r_p1_M60.npy")
epsilon_r_p1_M100=np.load("epsilon_r_p1_M100.npy")
epsilon_r_p1_M200=np.load("epsilon_r_p1_M200.npy")
epsilon_r_p1_M500=np.load("epsilon_r_p1_M500.npy")
epsilon_r_p1_M1000=np.load("epsilon_r_p1_M1000.npy")
#Y-axis, different values of mean value of sigma_x
sigma_x_p1_M1=np.load("sigma_x_p1_M1.npy")
sigma_x_p1_M10=np.load("sigma_x_p1_M10.npy")
sigma_x_p1_M30=np.load("sigma_x_p1_M30.npy")
sigma_x_p1_M60=np.load("sigma_x_p1_M60.npy")
sigma_x_p1_M100=np.load("sigma_x_p1_M100.npy")
sigma_x_p1_M200=np.load("sigma_x_p1_M200.npy")
sigma_x_p1_M500=np.load("sigma_x_p1_M500.npy")
sigma_x_p1_M1000=np.load("sigma_x_p1_M1000.npy")

# %%
#Option1
plt.plot(g,E_gs_p1_M1,label="$M=1$",linestyle='dotted')
plt.plot(g,E_gs_p1_M10,label="$M=10$")
plt.plot(g,E_gs_p1_M30,label="$M=30$")
plt.plot(g,E_gs_p1_M60,label="$M=60$")
plt.plot(g,E_gs_p1_M100,label="$M=100$")
plt.plot(g,E_gs_p1_M200,label="$M=200$")
plt.plot(g,E_gs_p1_M500,label="$M=500$")
plt.plot(g,E_gs_p1_M1000,label="$M=1000$",linestyle='dashed')
plt.xlabel('$g$')
plt.ylabel('$E_{GS}$')
plt.legend(loc='best')
plt.savefig('EGS_p1.png')
plt.show()

# %%
plt.plot(g,Delta_r_p1_M1,label="$M=1$",linestyle='dotted')
plt.plot(g,Delta_r_p1_M10,label="$M=10$")
plt.plot(g,Delta_r_p1_M30,label="$M=30$")
plt.plot(g,Delta_r_p1_M60,label="$M=60$")
plt.plot(g,Delta_r_p1_M100,label="$M=100$")
plt.plot(g,Delta_r_p1_M200,label="$M=200$")
plt.plot(g,Delta_r_p1_M500,label="$M=500$")
plt.plot(g,Delta_r_p1_M1000,label="$M=1000$", linestyle='dashed')
plt.xlabel('$g$')
plt.ylabel('$\Delta_r$')
plt.legend(loc='best')
plt.savefig('Delta_r_p1.png')
plt.show()

# %%
plt.plot(g,Delta_r_p1_M1,label="$M=1$",linestyle='dotted')
plt.plot(g,Delta_r_p1_M10,label="$M=10$")
plt.plot(g,Delta_r_p1_M30,label="$M=30$")
plt.plot(g,Delta_r_p1_M60,label="$M=60$")
plt.plot(g,Delta_r_p1_M100,label="$M=100$")
plt.plot(g,Delta_r_p1_M200,label="$M=200$")
plt.plot(g,Delta_r_p1_M500,label="$M=500$")
plt.plot(g,Delta_r_p1_M1000,label="$M=1000$", linestyle='dashed')
plt.xlabel('$g$')
plt.ylabel('$ \sigma^z = \Delta_r / \Delta$')
plt.legend(loc='best')
plt.savefig('sigmaz_p1.png')
plt.show()

# %%
#create Pe
Pe_p1_M1=(1-Delta_r_p1_M1)/2
Pe_p1_M10=(1-Delta_r_p1_M10)/2
Pe_p1_M30=(1-Delta_r_p1_M30)/2
Pe_p1_M60=(1-Delta_r_p1_M60)/2
Pe_p1_M100=(1-Delta_r_p1_M100)/2
Pe_p1_M200=(1-Delta_r_p1_M200)/2
Pe_p1_M500=(1-Delta_r_p1_M500)/2
Pe_p1_M1000=(1-Delta_r_p1_M1000)/2

plt.plot(g,Pe_p1_M1,label="$M=1$",linestyle='dotted')
plt.plot(g,Pe_p1_M10,label="$M=10$")
plt.plot(g,Pe_p1_M30,label="$M=30$")
plt.plot(g,Pe_p1_M60,label="$M=60$")
plt.plot(g,Pe_p1_M100,label="$M=100$")
plt.plot(g,Pe_p1_M200,label="$M=200$")
plt.plot(g,Pe_p1_M500,label="$M=500$")
plt.plot(g,Pe_p1_M1000,label="$M=1000$", linestyle='dashed')
plt.xlabel('$g$')
plt.ylabel('$P_e$')
plt.legend(loc='best')
plt.savefig('Pe_p1.png')
plt.show()

# %%
plt.plot(g,epsilon_r_p1_M1,label="$M=1$",linestyle='dotted')#poner tb el dolar en estas!!!!!!!!!!! por la cabecera que he puesto
plt.plot(g,epsilon_r_p1_M10,label="$M=10$")
plt.plot(g,epsilon_r_p1_M30,label="$M=30$")
plt.plot(g,epsilon_r_p1_M60,label="$M=60$")
plt.plot(g,epsilon_r_p1_M100,label="$M=100$")
plt.plot(g,epsilon_r_p1_M200,label="$M=200$")
plt.plot(g,epsilon_r_p1_M500,label="$M=500$")
plt.plot(g,epsilon_r_p1_M1000,label="$M=1000$",linestyle='dashed')
plt.xlabel('$g$')
plt.ylabel('$\epsilon_r$')
plt.legend(loc='best')
plt.savefig('epsilon_r_p1.png')
plt.show()

# %%
plt.plot(g,sigma_x_p1_M1,label="$M=1$",linestyle='dotted')
plt.plot(g,sigma_x_p1_M10,label="$M=10$")
plt.plot(g,sigma_x_p1_M30,label="$M=30$")
plt.plot(g,sigma_x_p1_M60,label="$M=60$")
plt.plot(g,sigma_x_p1_M100,label="$M=100$")
plt.plot(g,sigma_x_p1_M200,label="$M=200$")
plt.plot(g,sigma_x_p1_M500,label="$M=500$")
plt.plot(g,sigma_x_p1_M1000,label="$M=1000$",linestyle='dashed')
plt.xlabel('$g$')
plt.ylabel('$\sigma^x$')
plt.legend(loc='best')
plt.savefig('sigma_x_p1.png')
plt.show()

# %%
er_Wr_p1_M30=np.load("er_Wr_p1_M30.npy")
plt.plot(g,er_Wr_p1_M30)
plt.xlabel('$g$')
plt.ylabel('$\epsilon_r / W_r$')
plt.show()

# %%
M=100
delta=0.003
m=np.arange(1,M+1)
cks_mvar=0.2*np.sin(m*np.pi/2.)*np.sqrt(m)/(1.+delta*(m-1.))
plt.plot(m,cks_mvar)

# %%
#Option2
fig,ax=plt.subplots(1,1,figsize=(7.5,4.1))
th_array=[1,10,30,60,100,200,500,1000]
number=len(th_array)
colormap = cm.plasma
normalize = mcolors.Normalize(vmin=0, vmax=number-1) #color normalization as needed

th0=th_array[0]
color0 = colormap(normalize(0))
ax.scatter(g,E_gs_p1_M1,color=color0)
ax.plot(g,E_gs_p1_M1,color=color0)
ax.set_xlabel('$g$', fontsize=13)
ax.set_ylabel('$E_{GS}$', fontsize=13)

th1=th_array[1]
color1 = colormap(normalize(1))
ax.scatter(g,E_gs_p1_M10,color=color1)
ax.plot(g,E_gs_p1_M10,color=color1)
ax.set_xlabel('$g$', fontsize=13)
ax.set_ylabel('$E_{GS}$', fontsize=13)

th2=th_array[2]
color2 = colormap(normalize(2))
ax.scatter(g,E_gs_p1_M30,color=color2)
ax.plot(g,E_gs_p1_M30,color=color2)
ax.set_xlabel('$g$', fontsize=13)
ax.set_ylabel('$E_{GS}$', fontsize=13)

th3=th_array[3]
color3 = colormap(normalize(3))
ax.scatter(g,E_gs_p1_M60,color=color3)
ax.plot(g,E_gs_p1_M60,color=color3)
ax.set_xlabel('$g$', fontsize=13)
ax.set_ylabel('$E_{GS}$', fontsize=13)

th4=th_array[4]
color4 = colormap(normalize(4))
ax.scatter(g,E_gs_p1_M100,color=color4)
ax.plot(g,E_gs_p1_M100,color=color4)
ax.set_xlabel('$g$', fontsize=13)
ax.set_ylabel('$E_{GS}$', fontsize=13)

th5=th_array[5]
color5 = colormap(normalize(5))
ax.scatter(g,E_gs_p1_M200,color=color5)
ax.plot(g,E_gs_p1_M200,color=color5)
ax.set_xlabel('$g$', fontsize=13)
ax.set_ylabel('$E_{GS}$', fontsize=13)

th6=th_array[6]
color6 = colormap(normalize(6))
ax.scatter(g,E_gs_p1_M500,color=color6)
ax.plot(g,E_gs_p1_M500,color=color6)
ax.set_xlabel('$g$', fontsize=13)
ax.set_ylabel('$E_{GS}$', fontsize=13)

th7=th_array[7]
color7 = colormap(normalize(7))
ax.scatter(g,E_gs_p1_M1000,color=color7)
ax.plot(g,E_gs_p1_M1000,color=color7)
ax.set_xlabel('$g$', fontsize=13)
ax.set_ylabel('$E_{GS}$', fontsize=13)

normalize_bar=mcolors.Normalize(vmin=min(th_array), vmax=max(th_array))
cb = plt.colorbar(cm.ScalarMappable(norm=normalize_bar,cmap=cm.plasma), ax=ax,label="$M$")
cb.set_label(label="$M$",weight='bold',size=13,rotation=0,labelpad=10)
cb.ax.tick_params(labelsize=13)
cb.set_ticks([1,10,30,60,100,200,500,1000])

#fig.savefig('EGS_p1_option1.png')
