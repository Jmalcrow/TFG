# %%
import numpy as np
import matplotlib.pyplot as plt
import math
from copy import deepcopy
import matplotlib.colors as mcolors
import matplotlib.cm as cm
from matplotlib.ticker import ScalarFormatter

# %%
plt.rcParams['figure.figsize']=8.5,5.1
plt.rcParams['font.size']=28 #22
plt.rcParams['lines.linewidth']=2.1
plt.rcParams['text.usetex']=True

# %%
#X-axis, different values of coupling constant
g=np.arange(0,2,0.01)
#Y-axis, different values of Energy of Ground State
E_gs_p1_M1=np.load("EGS_p1_M1.npy")
E_gs_p1_M10=np.load("EGS_p1_M10.npy")
E_gs_p1_M30=np.load("EGS_p1_M30.npy")
E_gs_p1_M60=np.load("EGS_p1_M60.npy")
E_gs_p1_M100=np.load("EGS_p1_M100.npy")
E_gs_p1_M200=np.load("EGS_p1_M200.npy")
E_gs_p1_M500=np.load("EGS_p1_M500.npy")
E_gs_p1_M1000=np.load("EGS_p1_M1000.npy")
#Y-axis, different values of renormalized qubit frequency Delta_r
Delta_r_p1_M1=np.load("Delta_r_p1_M1.npy")
Delta_r_p1_M10=np.load("Delta_r_p1_M10.npy")
Delta_r_p1_M30=np.load("Delta_r_p1_M30.npy")
Delta_r_p1_M60=np.load("Delta_r_p1_M60.npy")
Delta_r_p1_M100=np.load("Delta_r_p1_M100.npy")
Delta_r_p1_M200=np.load("Delta_r_p1_M200.npy")
Delta_r_p1_M500=np.load("Delta_r_p1_M500.npy")
Delta_r_p1_M1000=np.load("Delta_r_p1_M1000.npy")
#Y-axis, different values of mean value of sigma_x
sigma_x_p1_M1=np.load("sigma_x_p1_M1.npy")
sigma_x_p1_M10=np.load("sigma_x_p1_M10.npy")
sigma_x_p1_M30=np.load("sigma_x_p1_M30.npy")
sigma_x_p1_M60=np.load("sigma_x_p1_M60.npy")
sigma_x_p1_M100=np.load("sigma_x_p1_M100.npy")
sigma_x_p1_M200=np.load("sigma_x_p1_M200.npy")
sigma_x_p1_M500=np.load("sigma_x_p1_M500.npy")
sigma_x_p1_M1000=np.load("sigma_x_p1_M1000.npy")
#Y-axis, different values of mean value of sigma_z
sigma_z_p1_M1=np.load("sigma_z_p1_M1.npy")
sigma_z_p1_M10=np.load("sigma_z_p1_M10.npy")
sigma_z_p1_M30=np.load("sigma_z_p1_M30.npy")
sigma_z_p1_M60=np.load("sigma_z_p1_M60.npy")
sigma_z_p1_M100=np.load("sigma_z_p1_M100.npy")
sigma_z_p1_M200=np.load("sigma_z_p1_M200.npy")
sigma_z_p1_M500=np.load("sigma_z_p1_M500.npy")
sigma_z_p1_M1000=np.load("sigma_z_p1_M1000.npy")
#Y-axis, different values of Energy of Ground State
E_gs_p2_M1=np.load("EGS_p2_M1.npy")
E_gs_p2_M10=np.load("EGS_p2_M10.npy")
E_gs_p2_M30=np.load("EGS_p2_M30.npy")
E_gs_p2_M60=np.load("EGS_p2_M60.npy")
E_gs_p2_M100=np.load("EGS_p2_M100.npy")
E_gs_p2_M200=np.load("EGS_p2_M200.npy")
E_gs_p2_M500=np.load("EGS_p2_M500.npy")
E_gs_p2_M1000=np.load("EGS_p2_M1000.npy")
#Y-axis, different values of renormalized qubit frequency Delta_r
Delta_r_p2_M1=np.load("Delta_r_p2_M1.npy")
Delta_r_p2_M10=np.load("Delta_r_p2_M10.npy")
Delta_r_p2_M30=np.load("Delta_r_p2_M30.npy")
Delta_r_p2_M60=np.load("Delta_r_p2_M60.npy")
Delta_r_p2_M100=np.load("Delta_r_p2_M100.npy")
Delta_r_p2_M200=np.load("Delta_r_p2_M200.npy")
Delta_r_p2_M500=np.load("Delta_r_p2_M500.npy")
Delta_r_p2_M1000=np.load("Delta_r_p2_M1000.npy")
#Y-axis, different values of renormalized bias epsilon_r
epsilon_r_p1_M1=np.load("epsilon_r_p1_M1.npy")
epsilon_r_p1_M10=np.load("epsilon_r_p1_M10.npy")
epsilon_r_p1_M30=np.load("epsilon_r_p1_M30.npy")
epsilon_r_p1_M60=np.load("epsilon_r_p1_M60.npy")
epsilon_r_p1_M100=np.load("epsilon_r_p1_M100.npy")
epsilon_r_p1_M200=np.load("epsilon_r_p1_M200.npy")
epsilon_r_p1_M500=np.load("epsilon_r_p1_M500.npy")
epsilon_r_p1_M1000=np.load("epsilon_r_p1_M1000.npy")
epsilon=0.001

# %%
fig = plt.figure(figsize=(24,7))


ax1 = fig.add_subplot(121)

ax1.spines['left'].set_linewidth(1.75)    #para cambiar el marco
ax1.spines['right'].set_linewidth(1.75)
ax1.spines['top'].set_linewidth(1.75)
ax1.spines['bottom'].set_linewidth(1.75)

ax1.tick_params(top = True, right=True, bottom = True, direction="in", width=1.6, length=8)  #para las marcas
ax1.set_xlabel('$g/\omega_c$',fontdict={'fontsize':34,'color':'k'},labelpad=8)
ax1.set_ylabel('$E_{GS,1}/\omega_c$',fontdict={'fontsize':34,'color':'k'},labelpad=6)
ax1.text(0.0,-487,"$(a)$", fontsize=30)
ax1.set_xlim([-0.05,2.05])
ax1.set_ylim([-525,25])
ax1.tick_params(pad=8)


cmap1 = plt.get_cmap('viridis')
Es=[E_gs_p1_M1,E_gs_p1_M10,E_gs_p1_M30,E_gs_p1_M60,E_gs_p1_M100,E_gs_p1_M200,E_gs_p1_M500,E_gs_p1_M1000]
labels=["$M=1$","$M=10$","$M=30$","$M=60$","$M=100$","$M=200$","$M=500$","$M=1000$"]
colors = iter(cmap1(np.linspace(0, 1, len(Es))))
for i in range (len(Es)):
    ax1.plot(g,Es[i],label=labels[i],c=next(colors))

    
ax2 = fig.add_subplot(122)

ax2.spines['left'].set_linewidth(1.75)
ax2.spines['right'].set_linewidth(1.75)
ax2.spines['top'].set_linewidth(1.75)
ax2.spines['bottom'].set_linewidth(1.75)

ax2.tick_params(top = True, right=True, bottom = True, direction="in", width=1.6, length=8)  #para las marcas
ax2.set_xlabel('$g/\omega_c$',fontdict={'fontsize':34,'color':'k'},labelpad=8)
ax2.set_ylabel('$E_{GS,2}/\omega_c$',fontdict={'fontsize':34,'color':'k'},labelpad=6)
ax2.text(0.0,-487,"$(b)$", fontsize=30)
ax2.set_xlim([-0.05,2.05])
ax2.set_ylim([-525,25])
ax2.tick_params(pad=8)

cmap2 = plt.get_cmap('viridis')
Es2=[E_gs_p2_M1,E_gs_p2_M10,E_gs_p2_M30,E_gs_p2_M60,E_gs_p2_M100,E_gs_p2_M200,E_gs_p2_M500,E_gs_p2_M1000]
labels=["$M=1$","$M=10$","$M=30$","$M=60$","$M=100$","$M=200$","$M=500$","$M=1000$"]
colors = iter(cmap2(np.linspace(0, 1, len(Es2))))
for i in range (len(Es2)):
    ax2.plot(g,Es2[i],label=labels[i],c=next(colors))

plt.legend(bbox_to_anchor=(0.6,1.3),ncol=4)
#plt.savefig('EGS_both.pdf',bbox_inches='tight')
#plt.show()

# %%
fig = plt.figure(figsize=(24,7))


ax1 = fig.add_subplot(121)

ax1.spines['left'].set_linewidth(1.75)    #para cambiar el marco
ax1.spines['right'].set_linewidth(1.75)
ax1.spines['top'].set_linewidth(1.75)
ax1.spines['bottom'].set_linewidth(1.75)

ax1.tick_params(top = True, right=True, bottom = True, direction="in", width=1.6, length=8)  #para las marcas
ax1.set_xlabel('$g/\omega_c$',fontdict={'fontsize':34,'color':'k'},labelpad=8)
ax1.set_ylabel('$\Delta_{r}/\Delta$',fontdict={'fontsize':34,'color':'k'},labelpad=8)
ax1.text(0.01,0.02,"$(a)$", fontsize=30)
ax1.set_xlim([-0.05,2.05])
ax1.set_ylim([-0.05,1.05])
ax1.tick_params(pad=8)


cmap1 = plt.get_cmap('viridis')
Deltas=[Delta_r_p1_M1,Delta_r_p1_M10,Delta_r_p1_M30,Delta_r_p1_M60,Delta_r_p1_M100,Delta_r_p1_M200,Delta_r_p1_M500,Delta_r_p1_M1000]
labels=["$M=1$","$M=10$","$M=30$","$M=60$","$M=100$","$M=200$","$M=500$","$M=1000$"]
colors = iter(cmap1(np.linspace(0, 1, len(Deltas))))
for i in range (len(Deltas)):
    ax1.plot(g,Deltas[i],label=labels[i],c=next(colors))

    
ax2 = fig.add_subplot(122)

ax2.spines['left'].set_linewidth(1.75)
ax2.spines['right'].set_linewidth(1.75)
ax2.spines['top'].set_linewidth(1.75)
ax2.spines['bottom'].set_linewidth(1.75)

ax2.tick_params(top = True, right=True, bottom = True, direction="in", width=1.6, length=8)  #para las marcas
ax2.set_xlabel('$g/\omega_c$',fontdict={'fontsize':34,'color':'k'},labelpad=8)
ax2.set_ylabel('$\epsilon_{r}/\epsilon$',fontdict={'fontsize':34,'color':'k'},labelpad=10)
ax2.text(1.88,1,"$(b)$", fontsize=30)
ax2.set_yticks([1.0,3.0,5.0,7.0])
#ax2.set_ylabels(["$1.0$","$3.0$","$5.0$","$7.0$"])
ax2.set_xlim([-0.05,2.05])
ax2.set_ylim([0.5,7.8])
ax2.tick_params(pad=8)

cmap2 = plt.get_cmap('viridis')
epss=[epsilon_r_p1_M1,epsilon_r_p1_M10,epsilon_r_p1_M30,epsilon_r_p1_M60,epsilon_r_p1_M100,epsilon_r_p1_M200,epsilon_r_p1_M500,epsilon_r_p1_M1000]
labels=["$M=1$","$M=10$","$M=30$","$M=60$","$M=100$","$M=200$","$M=500$","$M=1000$"]
colors = iter(cmap2(np.linspace(0, 1, len(epss))))
for i in range (len(epss)):
    ax2.plot(g,epss[i]/epsilon,label=labels[i],c=next(colors))

plt.legend(bbox_to_anchor=(0.6,1.3),ncol=4)
#plt.savefig('Deltaeps_p1.pdf',bbox_inches='tight')
#plt.show()

# %%
fig = plt.figure(figsize=(24,7))


ax1 = fig.add_subplot(121)

ax1.spines['left'].set_linewidth(1.75)    #para cambiar el marco
ax1.spines['right'].set_linewidth(1.75)
ax1.spines['top'].set_linewidth(1.75)
ax1.spines['bottom'].set_linewidth(1.75)

ax1.tick_params(top = True, right=True, bottom = True, direction="in", width=1.6, length=8)  #para las marcas
ax1.set_xlabel('$g/\omega_c$',fontdict={'fontsize':34,'color':'k'},labelpad=8)
ax1.set_ylabel('$ |<\sigma^z> |$',fontdict={'fontsize':34,'color':'k'},labelpad=8)
ax1.text(0.01,0.93,"$(a)$", fontsize=30)
ax1.set_xlim([-0.05,2.05])
ax1.set_ylim([-0.05,1.05])
ax1.tick_params(pad=8)


cmap1 = plt.get_cmap('viridis')
szs=[sigma_z_p1_M1,sigma_z_p1_M10,sigma_z_p1_M30,sigma_z_p1_M60,sigma_z_p1_M100,sigma_z_p1_M200,sigma_z_p1_M500,sigma_z_p1_M1000]
labels=["$M=1$","$M=10$","$M=30$","$M=60$","$M=100$","$M=200$","$M=500$","$M=1000$"]
colors = iter(cmap1(np.linspace(0, 1, len(szs))))
for i in range (len(szs)):
    ax1.plot(g,-szs[i],label=labels[i],c=next(colors))#ploteamos -sigmaz para tener valores positivos

    
ax2 = fig.add_subplot(122)

ax2.spines['left'].set_linewidth(1.75)
ax2.spines['right'].set_linewidth(1.75)
ax2.spines['top'].set_linewidth(1.75)
ax2.spines['bottom'].set_linewidth(1.75)

ax2.tick_params(top = True, right=True, bottom = True, direction="in", width=1.6, length=8)  #para las marcas
ax2.set_xlabel('$g/\omega_c$',fontdict={'fontsize':34,'color':'k'},labelpad=8)
ax2.set_ylabel('$|<\sigma^x>|$',fontdict={'fontsize':34,'color':'k'},labelpad=10)
ax2.text(1.88,0.93,"$(b)$", fontsize=30)
ax2.set_xlim([-0.05,2.05])
ax2.set_ylim([-0.05,1.05])
ax2.tick_params(pad=8)

cmap2 = plt.get_cmap('viridis')
sxs=[sigma_x_p1_M1,sigma_x_p1_M10,sigma_x_p1_M30,sigma_x_p1_M60,sigma_x_p1_M100,sigma_x_p1_M200,sigma_x_p1_M500,sigma_x_p1_M1000]
labels=["$M=1$","$M=10$","$M=30$","$M=60$","$M=100$","$M=200$","$M=500$","$M=1000$"]
colors = iter(cmap2(np.linspace(0, 1, len(sxs))))
for i in range (len(sxs)):
    ax2.plot(g,-sxs[i],label=labels[i],c=next(colors))#ploteamos -sigmax para valores positivos

plt.legend(bbox_to_anchor=(0.6,1.3),ncol=4)
#plt.savefig('sigmas_both.pdf',bbox_inches='tight')
#plt.show()

# %%
sp_sxs_M6_ncut5=np.load("sp_sxs_M6_ncut5.npy")
sp_sxs_M7_ncut5=np.load("sp_sxs_M7_ncut5.npy")
sp_sxs_M8_ncut5=np.load("sp_sxs_M8_ncut5.npy")
sp_sxs_M9_ncut5=np.load("sp_sxs_M9_ncut5.npy")
sp_szs_M6_ncut5=np.load("sp_szs_M6_ncut5.npy")
sp_szs_M7_ncut5=np.load("sp_szs_M7_ncut5.npy")
sp_szs_M8_ncut5=np.load("sp_szs_M8_ncut5.npy")
sp_szs_M9_ncut5=np.load("sp_szs_M9_ncut5.npy")

# %%
gs2=np.linspace(0,2,30)

fig = plt.figure(figsize=(24,7))


ax1 = fig.add_subplot(121)

ax1.spines['left'].set_linewidth(1.75)    #para cambiar el marco
ax1.spines['right'].set_linewidth(1.75)
ax1.spines['top'].set_linewidth(1.75)
ax1.spines['bottom'].set_linewidth(1.75)

ax1.tick_params(top = True, right=True, bottom = True, direction="in", width=1.6, length=8)  #para las marcas
ax1.set_xlabel('$g/\omega_c$',fontdict={'fontsize':34,'color':'k'},labelpad=8)
ax1.set_ylabel('$ |<\sigma^z> |$',fontdict={'fontsize':34,'color':'k'},labelpad=8)
ax1.text(0.01,0.93,"$(a)$", fontsize=30)
ax1.set_xlim([-0.05,2.05])
ax1.set_ylim([-0.05,1.05])
ax1.tick_params(pad=8)

   
cmap1 = plt.get_cmap('viridis')
szs4=[sp_szs_M6_ncut5,sp_szs_M7_ncut5,sp_szs_M8_ncut5,sp_szs_M9_ncut5]
labels4=["$M=6$","$M=7$","$M=8$","$M=9$"]
colors = iter(cmap1(np.linspace(0, 1, len(szs4))))
for i in range (len(szs4)):
    ax1.scatter(gs2,szs4[i],s=50,edgecolors=next(colors),facecolors='none',label=labels4[i],marker="o",linewidths=2)

szspolaron=np.load("sigma_z_p1_M1000.npy")
ax1.plot(g,-szspolaron,c="k",label="$Polaron \ M=1000$")



    
ax2 = fig.add_subplot(122)

ax2.spines['left'].set_linewidth(1.75)
ax2.spines['right'].set_linewidth(1.75)
ax2.spines['top'].set_linewidth(1.75)
ax2.spines['bottom'].set_linewidth(1.75)

ax2.tick_params(top = True, right=True, bottom = True, direction="in", width=1.6, length=8)  #para las marcas
ax2.set_xlabel('$g/\omega_c$',fontdict={'fontsize':34,'color':'k'},labelpad=8)
ax2.set_ylabel('$|<\sigma^x>|$',fontdict={'fontsize':34,'color':'k'},labelpad=10)
ax2.text(0.01,0.02,"$(b)$", fontsize=30)
ax2.set_xlim([-0.05,2.05])
ax2.set_ylim([-0.05,1.05])
ax2.tick_params(pad=8)

cmap2 = plt.get_cmap('viridis')
sxs4=[sp_sxs_M6_ncut5,sp_sxs_M7_ncut5,sp_sxs_M8_ncut5,sp_sxs_M9_ncut5]
labels4=["$M=6$","$M=7$","$M=8$","$M=9$"]
colors = iter(cmap2(np.linspace(0, 1, len(sxs4))))
for i in range (len(sxs4)):
    ax2.scatter(gs2,sxs4[i],s=50,edgecolors=next(colors),facecolors='none',label=labels4[i],marker="o",linewidths=2)

sxspolaron=np.load("sigma_x_p1_M1000.npy")
ax2.plot(g,-sxspolaron,c="k",label="$Polaron$")
ax2.legend(bbox_to_anchor=(1,1))

#plt.savefig('exact_sigmas_both.pdf',bbox_inches='tight')
#plt.show()
